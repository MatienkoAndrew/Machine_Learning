# %% [markdown]
# # Матиенко А.П. ИУ5-61Б, В-14

# %% [markdown]
# ### Для заданного набора данных проведите обработку пропусков в данных для одного категориального и одного количественного признака. Какие способы обработки пропусков в данных для категориальных и количественных признаков Вы использовали? Какие признаки Вы будете использовать для дальнейшего построения моделей машинного обучения и почему?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Извлечение dataset

# %%
import os
import zipfile

DATA_PATH = os.path.join('datasets')

def fetch_data(data_path=DATA_PATH):
    os.makedirs(data_path, exist_ok=True)
    zip_path = os.path.join(data_path, 'human-resources-data-set.zip')
    data_zip = zipfile.ZipFile(zip_path)
    data_zip.extractall(path=data_path)
    data_zip.close()

# %%
fetch_data()

# %%
def load_data(data_path=DATA_PATH):
    csv_path = os.path.join(data_path, 'HRDataset_v13.csv')
    return pd.read_csv(csv_path)

# %%
data = load_data()
data
# Out:
#             Employee_Name         EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0              Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1    LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2        Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3         Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4             Singh, Nan   1.307060e+09        0.0              0.0       0.0
# ..                    ...           ...        ...              ...       ...
# 396                   NaN           NaN        NaN              NaN       NaN
# 397                   NaN           NaN        NaN              NaN       NaN
# 398                   NaN           NaN        NaN              NaN       NaN
# 399                   NaN           NaN        NaN              NaN       NaN
# 400                   NaN           NaN        NaN              NaN       NaN
#
# ...

# %%
data.isnull().sum()
# Out:
# Employee_Name                  91
# EmpID                          91
# MarriedID                      91
# MaritalStatusID                91
# GenderID                       91
# EmpStatusID                    91
# DeptID                         91
# PerfScoreID                    91
# FromDiversityJobFairID         91
# PayRate                        91
# Termd                          91
# PositionID                     91
# Position                       91
# State                          91
# Zip                            91
# DOB                            91
# Sex                            91
# MaritalDesc                    91
# CitizenDesc                    91
# HispanicLatino                 91
# RaceDesc                       91
# DateofHire                     91
# DateofTermination             298
# TermReason                     92
# EmploymentStatus               91
# Department                     91
# ManagerName                    91
# ...

# %% [markdown]
# # В поле 'EngagementSurvey' пустые значения заменим на среднее

# %%
mean = data['EngagementSurvey'].mean()
data['EngagementSurvey'].fillna(mean, inplace=True)
data
# Out:
#             Employee_Name         EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0              Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1    LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2        Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3         Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4             Singh, Nan   1.307060e+09        0.0              0.0       0.0
# ..                    ...           ...        ...              ...       ...
# 396                   NaN           NaN        NaN              NaN       NaN
# 397                   NaN           NaN        NaN              NaN       NaN
# 398                   NaN           NaN        NaN              NaN       NaN
# 399                   NaN           NaN        NaN              NaN       NaN
# 400                   NaN           NaN        NaN              NaN       NaN
#
# ...

# %% [markdown]
# ## Категориальный признак 'Department':
# ## В нем пустые значение заменим на самые непопулярные из признака

# %%
departments = data['Department'].value_counts()
departments
# Out:
# Production              208
# IT/IS                    50
# Sales                    31
# Admin Offices            10
# Software Engineering     10
# Executive Office          1
# Name: Department, dtype: int64

# %%
sum_depart = data['Department'].count()
sum_depart
# Out:
# 310

# %%
list_prob = []
for department in departments.items():
    list_prob.append((department[0], department[1] / sum_depart))
list_prob.sort(key=lambda x: x[1])
list_prob
# Out:
# [('Executive Office', 0.0032258064516129032),
#  ('Admin Offices', 0.03225806451612903),
#  ('Software Engineering', 0.03225806451612903),
#  ('Sales', 0.1),
#  ('IT/IS', 0.16129032258064516),
#  ('Production       ', 0.6709677419354839)]

# %%
data['Department'].fillna('Executive Office', inplace=True)
data
# Out:
#             Employee_Name         EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0              Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1    LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2        Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3         Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4             Singh, Nan   1.307060e+09        0.0              0.0       0.0
# ..                    ...           ...        ...              ...       ...
# 396                   NaN           NaN        NaN              NaN       NaN
# 397                   NaN           NaN        NaN              NaN       NaN
# 398                   NaN           NaN        NaN              NaN       NaN
# 399                   NaN           NaN        NaN              NaN       NaN
# 400                   NaN           NaN        NaN              NaN       NaN
#
# ...

# %%
data['Department'].value_counts()
# Out:
# Production              208
# Executive Office         92
# IT/IS                    50
# Sales                    31
# Admin Offices            10
# Software Engineering     10
# Name: Department, dtype: int64

# %%
data['ManagerName'].value_counts()
# Out:
# Elijiah Gray          22
# Michael Albert        22
# Kissy Sullivan        22
# Kelley Spirea         22
# Brannon Miller        21
# Ketsia Liebig         21
# Amy Dunn              21
# David Stanley         21
# Webster Butler        21
# Janet King            19
# Simon Roup            17
# John Smith            14
# Peter Monroe          14
# Lynn Daneault         13
# Alex Sweetwater        9
# Brian Champaigne       8
# Brandon R. LeBlanc     7
# Jennifer Zamora        7
# Eric Dougall           4
# Debra Houlihan         3
# Board of Directors     2
# Name: ManagerName, dtype: int64

# %% [markdown]
# ## Пустые значения в признаке 'ManagerName' заменим на самые часто встречаемые

# %%
from sklearn.impute import SimpleImputer

imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imp.fit(data[['ManagerName']])
train = imp.transform(data[['ManagerName']])

# %%
data['ManagerName'] = train

# %%
data
# Out:
#             Employee_Name         EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0              Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1    LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2        Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3         Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4             Singh, Nan   1.307060e+09        0.0              0.0       0.0
# ..                    ...           ...        ...              ...       ...
# 396                   NaN           NaN        NaN              NaN       NaN
# 397                   NaN           NaN        NaN              NaN       NaN
# 398                   NaN           NaN        NaN              NaN       NaN
# 399                   NaN           NaN        NaN              NaN       NaN
# 400                   NaN           NaN        NaN              NaN       NaN
#
# ...
